# %%
import pandas as pd
import joblib as jb 

model=jb.load("rf_model.pkl")

new_data=pd.DataFrame({
    "total_orders": 17,
    "total_returns":4,
    "return_ratio":0.23,
    "order_value":2400,
    "acc_age_days": 23,
    "days_since_last_return":11,
    "return_last_7_days":1,
    "product_category": "home",
    "return_reason": "damaged",
    "is_high_value":0
    
    
}, index=[0])

pred=model.predict(new_data)[0]
prob=model.predict_proba(new_data)[0][1]

print("Prediction", pred)
print("Risk Score", prob)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2 import joblib as jb
#       3
#       4 model=jb.load("rf_model.pkl")
#       5
# ----> 6 new_data=pd.DataFrame({
#       7     "total_orders": 17,
#       8     "total_returns":4,
#       9     "return_ratio":0.23,
#
# File c:\Users\BIMAN\Desktop\ReturnShield AI\venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# ...
